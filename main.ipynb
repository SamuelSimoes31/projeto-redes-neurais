# %%
import pandas as pd
from scipy import stats
import numpy as np
import math

from sklearn.preprocessing import OneHotEncoder, OrdinalEncoder, MinMaxScaler
from sklearn.neural_network import MLPClassifier
from sklearn.pipeline import Pipeline
from sklearn.model_selection import train_test_split, GridSearchCV, cross_val_score, RandomizedSearchCV
from sklearn.metrics import classification_report, confusion_matrix, ConfusionMatrixDisplay

from itertools import product
from imblearn.over_sampling import RandomOverSampler
import matplotlib.pyplot as plt
import seaborn as sns

import torch
import torch.nn as nn
import torchvision.transforms
from torchvision.transforms import ToTensor
from torchvision.ops import MLP
from torch import optim

import tensorflow as tf
from tensorflow import keras
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Dropout
from tensorflow.keras import optimizers
from tensorflow.keras import regularizers

from IPython.display import clear_output

# %%
train_df = pd.read_csv('database/train.csv', index_col=0)
test_df = pd.read_csv('database/test.csv', index_col=0)
train_df.head()
# Out:
#        id  Gender      Customer Type  Age   Type of Travel     Class  \
# 0   70172    Male     Loyal Customer   13  Personal Travel  Eco Plus
# 1    5047    Male  disloyal Customer   25  Business travel  Business
# 2  110028  Female     Loyal Customer   26  Business travel  Business
# 3   24026  Female     Loyal Customer   25  Business travel  Business
# 4  119299    Male     Loyal Customer   61  Business travel  Business
#
#    Flight Distance  Inflight wifi service  Departure/Arrival time convenient  \
# 0              460                      3                                  4
# 1              235                      3                                  2
# 2             1142                      2                                  2
# 3              562                      2                                  5
# 4              214                      3                                  3
#
#    Ease of Online booking  ...  Inflight entertainment  On-board service  \
# 0                       3  ...                       5                 4
# 1                       3  ...                       1                 1
# 2                       2  ...                       5                 4
# 3                       5  ...                       2                 2
# 4                       3  ...                       3                 3
#
#    Leg room service  Baggage handling  Checkin service  Inflight service  \
# 0                 3                 4                4                 5
# 1                 5                 3                1                 4
# 2                 3                 4                4                 4
# 3                 5                 3                1                 4
# 4                 4                 4                3                 3
#
#    Cleanliness  Departure Delay in Minutes  Arrival Delay in Minutes  \
# 0            5                          25                      18.0
# 1            1                           1                       6.0
# 2            5                           0                       0.0
# 3            2                          11                       9.0
# 4            3                           0                       0.0
#
#               satisfaction
# 0  neutral or dissatisfied
# 1  neutral or dissatisfied
# 2                satisfied
# 3  neutral or dissatisfied
# 4                satisfied
#
# [5 rows x 24 columns]

# %% [markdown]
# # Train Validation Split

# %%
original_df = train_df.drop(columns=['id'])
test_df = test_df.drop(columns=['id'])

# %%
train_df, validation_df = train_test_split(original_df,test_size= 0.25, stratify=original_df['satisfaction'])

print('original_df: ',len(original_df))
print('train_df size: ', len(train_df), "| validation_df size:", len(validation_df))
print(f'train_df: {len(train_df)/len(original_df)}%', f"| validation_df: {len(validation_df)/len(original_df)}%",)
# Out:
# original_df:  103904
# train_df size:  77928 | validation_df size: 25976
# train_df: 0.75% | validation_df: 0.25%

# %% [markdown]
# # Outliers

# %%
train_df.reset_index(drop=True, inplace=True)

cols = ['Age', 'Flight Distance', 'Departure Delay in Minutes', 'Arrival Delay in Minutes']

sns.set_theme(rc={'figure.figsize':(11.7,8.27)})

sns.boxplot(data=train_df[cols])
# Out:
# <Axes: >

# %%
print("Original DataFrame Shape:", train_df.shape)
z_score_col = []
for cl in cols:
    z = np.abs(stats.zscore(train_df[cl]))
    outlier_set = (np.where(z > 3)[0])
    train_df = train_df.drop(index=outlier_set)
    train_df.reset_index(drop=True, inplace=True)
    if len(outlier_set > 0):
        z_score_col.append(cl)


print("DataFrame Shape after Removing Outliers:", train_df.shape)
print('Columns with z-score > 3: ', z_score_col)

sns.boxplot(data=train_df[cols])
# Out:
# Original DataFrame Shape: (77928, 23)
# DataFrame Shape after Removing Outliers: (76169, 23)
# Columns with z-score > 3:  ['Age', 'Flight Distance', 'Departure Delay in Minutes']
# <Axes: >

# %% [markdown]
# # Enconding

# %% [markdown]
# ## Class Variable

# %%
classes_dict = {
    'neutral or dissatisfied': 0,
    'satisfied': 1
}
def ord_encode(x):
    return classes_dict[x]

dec_class = 'satisfaction'
print('Before Encoding: ', train_df[dec_class].values)
train_df[dec_class] = train_df[dec_class].map(ord_encode)
validation_df[dec_class] = validation_df[dec_class].map(ord_encode)
print('After Encoding: ', train_df[dec_class].values)
# Out:
# Before Encoding:  ['satisfied' 'neutral or dissatisfied' 'satisfied' ... 'satisfied'
#  'neutral or dissatisfied' 'neutral or dissatisfied']
# After Encoding:  [1 0 1 ... 1 0 0]

# %% [markdown]
# ## One Hot Enconding

# %%
one_hot_encoder_vars = ['Type of Travel', 'Gender', 'Customer Type']
validation_df = pd.get_dummies(validation_df, columns=one_hot_encoder_vars, drop_first=True)
train_df = pd.get_dummies(train_df, columns=one_hot_encoder_vars, drop_first=True)
train_df[['Type of Travel_Personal Travel', 'Gender_Male',  'Customer Type_disloyal Customer']]
# Out:
#        Type of Travel_Personal Travel  Gender_Male  \
# 0                               False        False
# 1                                True        False
# 2                               False        False
# 3                               False         True
# 4                               False        False
# ...                               ...          ...
# 76164                           False         True
# 76165                            True        False
# 76166                           False         True
# 76167                           False         True
# 76168                           False         True
#
#        Customer Type_disloyal Customer
# 0                                False
# 1                                False
# 2                                False
# 3                                 True
# 4                                False
# ...                                ...
# 76164                            False
# 76165                            False
# 76166                             True
# 76167                            False
# 76168                            False
#
# [76169 rows x 3 columns]

# %% [markdown]
# ## Ordinal Enconding

# %%
classes_dict = {
    'Eco': 0,
    'Eco Plus': 1,
    'Business': 2
}
def ord_encode(x):
    return classes_dict[x]

ordinal_encoder_vars = ['Class']
print('Before Encoding: ', train_df[ordinal_encoder_vars].values)
train_df[ordinal_encoder_vars] = train_df[ordinal_encoder_vars].applymap(ord_encode)
validation_df[ordinal_encoder_vars] = validation_df[ordinal_encoder_vars].applymap(ord_encode)
print('After Encoding: ', train_df[ordinal_encoder_vars].values)
# Out:
# Before Encoding:  [['Business']
#  ['Business']
#  ['Business']
#  ...
#  ['Business']
#  ['Business']
#  ['Eco Plus']]
# After Encoding:  [[2]
#  [2]
#  [2]
#  ...
#  [2]
#  [2]
#  [1]]

# %% [markdown]
# # Correlation

# %% [markdown]
# ## Continuous Variables

# %% [markdown]
# Needs to be done before Binning

# %%
columns = ['Age', 'Departure Delay in Minutes', 'Arrival Delay in Minutes', 'Flight Distance']

corr = train_df[columns].corr(method='spearman')
# Generate a mask for the upper triangle
mask = np.zeros_like(corr, dtype=bool)
mask[np.triu_indices_from(mask)] = True

# Set up the matplotlib figure
f, ax = plt.subplots(figsize=(20, 18))

# Draw the heatmap with the mask and correct aspect ratio
sns.heatmap(corr, annot = True, cmap="YlGnBu", center=0,
           square=True, linewidths=.5)
# Out:
# <Axes: >

# %%
corr
# Out:
#                                  Age  Departure Delay in Minutes  \
# Age                         1.000000                   -0.009833
# Departure Delay in Minutes -0.009833                    1.000000
# Arrival Delay in Minutes   -0.012248                    0.719080
# Flight Distance             0.074023                    0.026092
#
#                             Arrival Delay in Minutes  Flight Distance
# Age                                        -0.012248         0.074023
# Departure Delay in Minutes                  0.719080         0.026092
# Arrival Delay in Minutes                    1.000000        -0.005265
# Flight Distance                            -0.005265         1.000000

# %% [markdown]
# ## Categorical Variables (Chi Squared Test)

# %%
columns = ['Class', 'Inflight wifi service',
       'Departure/Arrival time convenient', 'Ease of Online booking',
       'Gate location', 'Food and drink', 'Online boarding', 'Seat comfort',
       'Inflight entertainment', 'On-board service', 'Leg room service',
       'Baggage handling', 'Checkin service', 'Inflight service',
       'Cleanliness', 'satisfaction', 'Type of Travel_Personal Travel', 'Gender_Male',
       'Customer Type_disloyal Customer']

print('Shape Before dropna: ', train_df[columns].shape)
df_corr = train_df[columns].dropna()
print('Shape After dropna: ', df_corr.shape)

cat_var_prod = list(product(columns,columns, repeat = 1))

result = []
for i in cat_var_prod:
       if i[0] != i[1]:
              result.append((i[0],i[1],list(stats.chi2_contingency(pd.crosstab(df_corr[i[0]], df_corr[i[1]])))[1]))
result
# Out:
# Shape Before dropna:  (76169, 19)
# Shape After dropna:  (76169, 19)
# [('Class', 'Inflight wifi service', 0.0),
#  ('Class', 'Departure/Arrival time convenient', 0.0),
#  ('Class', 'Ease of Online booking', 0.0),
#  ('Class', 'Gate location', 0.0),
#  ('Class', 'Food and drink', 1.2299926779791847e-188),
#  ('Class', 'Online boarding', 0.0),
#  ('Class', 'Seat comfort', 0.0),
#  ('Class', 'Inflight entertainment', 0.0),
#  ('Class', 'On-board service', 0.0),
#  ('Class', 'Leg room service', 0.0),
#  ('Class', 'Baggage handling', 0.0),
#  ('Class', 'Checkin service', 0.0),
#  ('Class', 'Inflight service', 0.0),
#  ('Class', 'Cleanliness', 0.0),
#  ('Class', 'satisfaction', 0.0),
#  ('Class', 'Type of Travel_Personal Travel', 0.0),
#  ('Class', 'Gender_Male', 0.0014606703120446693),
#  ('Class', 'Customer Type_disloyal Customer', 6.3329351745467506e-260),
#  ('Inflight wifi service', 'Class', 0.0),
#  ('Inflight wifi service', 'Departure/Arrival time convenient', 0.0),
#  ('Inflight wifi service', 'Ease of Online booking', 0.0),
#  ('Inflight wifi service', 'Gate location', 0.0),
#  ('Inflight wifi service', 'Food and drink', 0.0),
#  ('Inflight wifi service', 'Online boarding', 0.0),
#  ('Inflight wifi service', 'Seat comfort', 0.0),
#  ('Inflight wifi service', 'Inflight entertainment', 0.0),
#  ('Inflight wifi service', 'On-board service', 0.0),
#  ('Inflight wifi service', 'Leg room service', 0.0),
#  ('Inflight wifi service', 'Baggage handling', 0.0),
#  ('Inflight wifi service', 'Checkin service', 6.679548262463715e-134),
#  ('Inflight wifi service', 'Inflight service', 0.0),
#  ('Inflight wifi service', 'Cleanliness', 0.0),
#  ('Inflight wifi service', 'satisfaction', 0.0),
#  ('Inflight wifi service', 'Type of Travel_Personal Travel', 0.0),
#  ('Inflight wifi service', 'Gender_Male', 0.007230574889666334),
#  ('Inflight wifi service',
#   'Customer Type_disloyal Customer',
#   2.303399929290052e-26),
#  ('Departure/Arrival time convenient', 'Class', 0.0),
#  ('Departure/Arrival time convenient', 'Inflight wifi service', 0.0),
#  ('Departure/Arrival time convenient', 'Ease of Online booking', 0.0),
#  ('Departure/Arrival time convenient', 'Gate location', 0.0),
#  ('Departure/Arrival time convenient',
#   'Food and drink',
#   4.611598912918311e-11),
#  ('Departure/Arrival time convenient', 'Online boarding', 0.0),
#  ('Departure/Arrival time convenient', 'Seat comfort', 5.7464188957569556e-46),
#  ('Departure/Arrival time convenient',
#   'Inflight entertainment',
#   9.607176590323719e-69),
#  ('Departure/Arrival time convenient',
#   'On-board service',
#   4.185426663481122e-172),
#  ('Departure/Arrival time convenient',
#   'Leg room service',
#   7.457075753748882e-106),
#  ('Departure/Arrival time convenient',
#   'Baggage handling',
#   3.3672657706070875e-300),
#  ('Departure/Arrival time convenient', 'Checkin service', 0.0),
#  ('Departure/Arrival time convenient', 'Inflight service', 0.0),
#  ('Departure/Arrival time convenient', 'Cleanliness', 6.662029426138476e-10),
#  ('Departure/Arrival time convenient', 'satisfaction', 6.465334170028056e-67),
#  ('Departure/Arrival time convenient', 'Type of Travel_Personal Travel', 0.0),
#  ('Departure/Arrival time convenient', 'Gender_Male', 0.044713275555195546),
#  ('Departure/Arrival time convenient', 'Customer Type_disloyal Customer', 0.0),
#  ('Ease of Online booking', 'Class', 0.0),
#  ('Ease of Online booking', 'Inflight wifi service', 0.0),
#  ('Ease of Online booking', 'Departure/Arrival time convenient', 0.0),
#  ('Ease of Online booking', 'Gate location', 0.0),
#  ('Ease of Online booking', 'Food and drink', 1.6999948358998226e-84),
#  ('Ease of Online booking', 'Online boarding', 0.0),
#  ('Ease of Online booking', 'Seat comfort', 6.028785194631736e-38),
#  ('Ease of Online booking', 'Inflight entertainment', 2.0126293722194445e-78),
#  ('Ease of Online booking', 'On-board service', 7.434518585591936e-36),
#  ('Ease of Online booking', 'Leg room service', 0.0),
#  ('Ease of Online booking', 'Baggage handling', 3.805691870202462e-54),
#  ('Ease of Online booking', 'Checkin service', 1.1720179806599629e-19),
#  ('Ease of Online booking', 'Inflight service', 1.88093747829324e-42),
#  ('Ease of Online booking', 'Cleanliness', 2.585757224709001e-15),
#  ('Ease of Online booking', 'satisfaction', 0.0),
#  ('Ease of Online booking', 'Type of Travel_Personal Travel', 0.0),
#  ('Ease of Online booking', 'Gender_Male', 0.031225282566494178),
#  ('Ease of Online booking',
#   'Customer Type_disloyal Customer',
#   4.077925300595835e-49),
#  ('Gate location', 'Class', 0.0),
#  ('Gate location', 'Inflight wifi service', 0.0),
#  ('Gate location', 'Departure/Arrival time convenient', 0.0),
#  ('Gate location', 'Ease of Online booking', 0.0),
#  ('Gate location', 'Food and drink', 1.154192478330031e-17),
#  ('Gate location', 'Online boarding', 1.9564358161449858e-197),
#  ('Gate location', 'Seat comfort', 7.848534566252169e-64),
#  ('Gate location', 'Inflight entertainment', 2.2195359887447544e-61),
#  ('Gate location', 'On-board service', 3.2433586255233587e-115),
#  ('Gate location', 'Leg room service', 7.188389228067833e-60),
#  ('Gate location', 'Baggage handling', 1.1410868165462405e-173),
#  ('Gate location', 'Checkin service', 2.4378422232992365e-102),
#  ('Gate location', 'Inflight service', 2.266637202993902e-188),
#  ('Gate location', 'Cleanliness', 2.0998795998992637e-36),
#  ('Gate location', 'satisfaction', 0.0),
#  ('Gate location', 'Type of Travel_Personal Travel', 0.0),
#  ('Gate location', 'Gender_Male', 0.15940519458522426),
#  ('Gate location', 'Customer Type_disloyal Customer', 9.285889240489636e-251),
#  ('Food and drink', 'Class', 1.2299926779791146e-188),
#  ('Food and drink', 'Inflight wifi service', 0.0),
#  ('Food and drink',
#   'Departure/Arrival time convenient',
#   4.6115989129183804e-11),
#  ('Food and drink', 'Ease of Online booking', 1.699994835899774e-84),
#  ('Food and drink', 'Gate location', 1.154192478330031e-17),
#  ('Food and drink', 'Online boarding', 0.0),
#  ('Food and drink', 'Seat comfort', 0.0),
#  ('Food and drink', 'Inflight entertainment', 0.0),
#  ('Food and drink', 'On-board service', 2.0505013393062078e-67),
#  ('Food and drink', 'Leg room service', 1.741509843095865e-45),
#  ('Food and drink', 'Baggage handling', 1.5535892497473618e-67),
#  ('Food and drink', 'Checkin service', 2.64778210457084e-134),
#  ('Food and drink', 'Inflight service', 5.013988299126123e-57),
#  ('Food and drink', 'Cleanliness', 0.0),
#  ('Food and drink', 'satisfaction', 0.0),
#  ('Food and drink', 'Type of Travel_Personal Travel', 1.9848059153352914e-84),
#  ('Food and drink', 'Gender_Male', 0.019859403155602705),
#  ('Food and drink',
#   'Customer Type_disloyal Customer',
#   1.1284421002621692e-102),
#  ('Online boarding', 'Class', 0.0),
#  ('Online boarding', 'Inflight wifi service', 0.0),
#  ('Online boarding', 'Departure/Arrival time convenient', 0.0),
#  ('Online boarding', 'Ease of Online booking', 0.0),
#  ('Online boarding', 'Gate location', 1.9564358161448744e-197),
#  ('Online boarding', 'Food and drink', 0.0),
#  ('Online boarding', 'Seat comfort', 0.0),
#  ('Online boarding', 'Inflight entertainment', 0.0),
#  ('Online boarding', 'On-board service', 0.0),
#  ('Online boarding', 'Leg room service', 0.0),
#  ('Online boarding', 'Baggage handling', 0.0),
#  ('Online boarding', 'Checkin service', 0.0),
#  ('Online boarding', 'Inflight service', 0.0),
#  ('Online boarding', 'Cleanliness', 0.0),
#  ('Online boarding', 'satisfaction', 0.0),
#  ('Online boarding', 'Type of Travel_Personal Travel', 0.0),
#  ('Online boarding', 'Gender_Male', 2.290559163595305e-29),
#  ('Online boarding', 'Customer Type_disloyal Customer', 0.0),
#  ('Seat comfort', 'Class', 0.0),
#  ('Seat comfort', 'Inflight wifi service', 0.0),
#  ('Seat comfort', 'Departure/Arrival time convenient', 5.7464188957569556e-46),
#  ('Seat comfort', 'Ease of Online booking', 6.028785194631736e-38),
#  ('Seat comfort', 'Gate location', 7.848534566252169e-64),
#  ('Seat comfort', 'Food and drink', 0.0),
#  ('Seat comfort', 'Online boarding', 0.0),
#  ('Seat comfort', 'Inflight entertainment', 0.0),
#  ('Seat comfort', 'On-board service', 0.0),
#  ('Seat comfort', 'Leg room service', 0.0),
#  ('Seat comfort', 'Baggage handling', 0.0),
#  ('Seat comfort', 'Checkin service', 0.0),
#  ('Seat comfort', 'Inflight service', 0.0),
#  ('Seat comfort', 'Cleanliness', 0.0),
#  ('Seat comfort', 'satisfaction', 0.0),
#  ('Seat comfort', 'Type of Travel_Personal Travel', 2.039370099071688e-282),
#  ('Seat comfort', 'Gender_Male', 2.464560511219716e-23),
#  ('Seat comfort', 'Customer Type_disloyal Customer', 0.0),
#  ('Inflight entertainment', 'Class', 0.0),
#  ('Inflight entertainment', 'Inflight wifi service', 0.0),
#  ('Inflight entertainment',
#   'Departure/Arrival time convenient',
#   9.607176590323719e-69),
#  ('Inflight entertainment', 'Ease of Online booking', 2.012629372219503e-78),
#  ('Inflight entertainment', 'Gate location', 2.219535988744817e-61),
#  ('Inflight entertainment', 'Food and drink', 0.0),
#  ('Inflight entertainment', 'Online boarding', 0.0),
#  ('Inflight entertainment', 'Seat comfort', 0.0),
#  ('Inflight entertainment', 'On-board service', 0.0),
#  ('Inflight entertainment', 'Leg room service', 0.0),
#  ('Inflight entertainment', 'Baggage handling', 0.0),
#  ('Inflight entertainment', 'Checkin service', 0.0),
#  ('Inflight entertainment', 'Inflight service', 0.0),
#  ('Inflight entertainment', 'Cleanliness', 0.0),
#  ('Inflight entertainment', 'satisfaction', 0.0),
#  ('Inflight entertainment', 'Type of Travel_Personal Travel', 0.0),
#  ('Inflight entertainment', 'Gender_Male', 0.13081270347819088),
#  ('Inflight entertainment',
#   'Customer Type_disloyal Customer',
#   4.4058878323521755e-234),
#  ('On-board service', 'Class', 0.0),
#  ('On-board service', 'Inflight wifi service', 0.0),
#  ('On-board service',
#   'Departure/Arrival time convenient',
#   4.185426663480885e-172),
#  ('On-board service', 'Ease of Online booking', 7.434518585591936e-36),
#  ('On-board service', 'Gate location', 3.2433586255231734e-115),
#  ('On-board service', 'Food and drink', 2.0505013393061495e-67),
#  ('On-board service', 'Online boarding', 0.0),
#  ('On-board service', 'Seat comfort', 0.0),
#  ('On-board service', 'Inflight entertainment', 0.0),
#  ('On-board service', 'Leg room service', 0.0),
#  ('On-board service', 'Baggage handling', 0.0),
#  ('On-board service', 'Checkin service', 0.0),
#  ('On-board service', 'Inflight service', 0.0),
#  ('On-board service', 'Cleanliness', 1.9302352423965332e-293),
#  ('On-board service', 'satisfaction', 0.0),
#  ('On-board service',
#   'Type of Travel_Personal Travel',
#   1.0632679530961453e-121),
#  ('On-board service', 'Gender_Male', 9.755153362817097e-08),
#  ('On-board service',
#   'Customer Type_disloyal Customer',
#   7.728453012143891e-109),
#  ('Leg room service', 'Class', 0.0),
#  ('Leg room service', 'Inflight wifi service', 0.0),
#  ('Leg room service',
#   'Departure/Arrival time convenient',
#   7.457075753748459e-106),
#  ('Leg room service', 'Ease of Online booking', 0.0),
#  ('Leg room service', 'Gate location', 7.188389228068041e-60),
#  ('Leg room service', 'Food and drink', 1.741509843095815e-45),
#  ('Leg room service', 'Online boarding', 0.0),
#  ('Leg room service', 'Seat comfort', 0.0),
#  ('Leg room service', 'Inflight entertainment', 0.0),
#  ('Leg room service', 'On-board service', 0.0),
#  ('Leg room service', 'Baggage handling', 0.0),
#  ('Leg room service', 'Checkin service', 0.0),
#  ('Leg room service', 'Inflight service', 0.0),
#  ('Leg room service', 'Cleanliness', 5.152921650338204e-218),
#  ('Leg room service', 'satisfaction', 0.0),
#  ('Leg room service', 'Type of Travel_Personal Travel', 0.0),
#  ('Leg room service', 'Gender_Male', 3.2810001909853636e-50),
#  ('Leg room service',
#   'Customer Type_disloyal Customer',
#   1.0807197359750519e-100),
#  ('Baggage handling', 'Class', 0.0),
#  ('Baggage handling', 'Inflight wifi service', 0.0),
#  ('Baggage handling',
#   'Departure/Arrival time convenient',
#   3.3672657706070875e-300),
#  ('Baggage handling', 'Ease of Online booking', 3.8056918702022976e-54),
#  ('Baggage handling', 'Gate location', 1.1410868165462403e-173),
#  ('Baggage handling', 'Food and drink', 1.5535892497473618e-67),
#  ('Baggage handling', 'Online boarding', 0.0),
#  ('Baggage handling', 'Seat comfort', 0.0),
#  ('Baggage handling', 'Inflight entertainment', 0.0),
#  ('Baggage handling', 'On-board service', 0.0),
#  ('Baggage handling', 'Leg room service', 0.0),
#  ('Baggage handling', 'Checkin service', 0.0),
#  ('Baggage handling', 'Inflight service', 0.0),
#  ('Baggage handling', 'Cleanliness', 3.212623047748393e-243),
#  ('Baggage handling', 'satisfaction', 0.0),
#  ('Baggage handling',
#   'Type of Travel_Personal Travel',
#   4.9711840650948436e-45),
#  ('Baggage handling', 'Gender_Male', 3.4905305920237737e-44),
#  ('Baggage handling',
#   'Customer Type_disloyal Customer',
#   1.6824613018651154e-73),
#  ('Checkin service', 'Class', 0.0),
#  ('Checkin service', 'Inflight wifi service', 6.679548262463715e-134),
#  ('Checkin service', 'Departure/Arrival time convenient', 0.0),
#  ('Checkin service', 'Ease of Online booking', 1.1720179806599797e-19),
#  ('Checkin service', 'Gate location', 2.4378422232992365e-102),
#  ('Checkin service', 'Food and drink', 2.64778210457084e-134),
#  ('Checkin service', 'Online boarding', 0.0),
#  ('Checkin service', 'Seat comfort', 0.0),
#  ('Checkin service', 'Inflight entertainment', 0.0),
#  ('Checkin service', 'On-board service', 0.0),
#  ('Checkin service', 'Leg room service', 0.0),
#  ('Checkin service', 'Baggage handling', 0.0),
#  ('Checkin service', 'Inflight service', 0.0),
#  ('Checkin service', 'Cleanliness', 0.0),
#  ('Checkin service', 'satisfaction', 0.0),
#  ('Checkin service', 'Type of Travel_Personal Travel', 9.434453466716218e-07),
#  ('Checkin service', 'Gender_Male', 0.002743413099379015),
#  ('Checkin service',
#   'Customer Type_disloyal Customer',
#   3.1996642662667664e-17),
#  ('Inflight service', 'Class', 0.0),
#  ('Inflight service', 'Inflight wifi service', 0.0),
#  ('Inflight service', 'Departure/Arrival time convenient', 0.0),
#  ('Inflight service', 'Ease of Online booking', 1.8809374782932945e-42),
#  ('Inflight service', 'Gate location', 2.266637202993902e-188),
#  ('Inflight service', 'Food and drink', 5.013988299126266e-57),
#  ('Inflight service', 'Online boarding', 0.0),
#  ('Inflight service', 'Seat comfort', 0.0),
#  ('Inflight service', 'Inflight entertainment', 0.0),
#  ('Inflight service', 'On-board service', 0.0),
#  ('Inflight service', 'Leg room service', 0.0),
#  ('Inflight service', 'Baggage handling', 0.0),
#  ('Inflight service', 'Checkin service', 0.0),
#  ('Inflight service', 'Cleanliness', 7.73162218040077e-209),
#  ('Inflight service', 'satisfaction', 0.0),
#  ('Inflight service',
#   'Type of Travel_Personal Travel',
#   1.9030260948645452e-31),
#  ('Inflight service', 'Gender_Male', 9.45106746482348e-36),
#  ('Inflight service',
#   'Customer Type_disloyal Customer',
#   3.1785619604175804e-53),
#  ('Cleanliness', 'Class', 0.0),
#  ('Cleanliness', 'Inflight wifi service', 0.0),
#  ('Cleanliness', 'Departure/Arrival time convenient', 6.662029426138426e-10),
#  ('Cleanliness', 'Ease of Online booking', 2.585757224709001e-15),
#  ('Cleanliness', 'Gate location', 2.0998795998992637e-36),
#  ('Cleanliness', 'Food and drink', 0.0),
#  ('Cleanliness', 'Online boarding', 0.0),
#  ('Cleanliness', 'Seat comfort', 0.0),
#  ('Cleanliness', 'Inflight entertainment', 0.0),
#  ('Cleanliness', 'On-board service', 1.9302352423967532e-293),
#  ('Cleanliness', 'Leg room service', 5.152921650337615e-218),
#  ('Cleanliness', 'Baggage handling', 3.212623047748393e-243),
#  ('Cleanliness', 'Checkin service', 0.0),
#  ('Cleanliness', 'Inflight service', 7.731622180399887e-209),
#  ('Cleanliness', 'satisfaction', 0.0),
#  ('Cleanliness', 'Type of Travel_Personal Travel', 2.5714781945750343e-136),
#  ('Cleanliness', 'Gender_Male', 2.7883904307711063e-06),
#  ('Cleanliness', 'Customer Type_disloyal Customer', 3.274152715269165e-182),
#  ('satisfaction', 'Class', 0.0),
#  ('satisfaction', 'Inflight wifi service', 0.0),
#  ('satisfaction', 'Departure/Arrival time convenient', 6.465334170028241e-67),
#  ('satisfaction', 'Ease of Online booking', 0.0),
#  ('satisfaction', 'Gate location', 0.0),
#  ('satisfaction', 'Food and drink', 0.0),
#  ('satisfaction', 'Online boarding', 0.0),
#  ('satisfaction', 'Seat comfort', 0.0),
#  ('satisfaction', 'Inflight entertainment', 0.0),
#  ('satisfaction', 'On-board service', 0.0),
#  ('satisfaction', 'Leg room service', 0.0),
#  ('satisfaction', 'Baggage handling', 0.0),
#  ('satisfaction', 'Checkin service', 0.0),
#  ('satisfaction', 'Inflight service', 0.0),
#  ('satisfaction', 'Cleanliness', 0.0),
#  ('satisfaction', 'Type of Travel_Personal Travel', 0.0),
#  ('satisfaction', 'Gender_Male', 8.095829340346903e-05),
#  ('satisfaction', 'Customer Type_disloyal Customer', 0.0),
#  ('Type of Travel_Personal Travel', 'Class', 0.0),
#  ('Type of Travel_Personal Travel', 'Inflight wifi service', 0.0),
#  ('Type of Travel_Personal Travel', 'Departure/Arrival time convenient', 0.0),
#  ('Type of Travel_Personal Travel', 'Ease of Online booking', 0.0),
#  ('Type of Travel_Personal Travel', 'Gate location', 0.0),
#  ('Type of Travel_Personal Travel', 'Food and drink', 1.9848059153352914e-84),
#  ('Type of Travel_Personal Travel', 'Online boarding', 0.0),
#  ('Type of Travel_Personal Travel', 'Seat comfort', 2.039370099071688e-282),
#  ('Type of Travel_Personal Travel', 'Inflight entertainment', 0.0),
#  ('Type of Travel_Personal Travel',
#   'On-board service',
#   1.0632679530961453e-121),
#  ('Type of Travel_Personal Travel', 'Leg room service', 0.0),
#  ('Type of Travel_Personal Travel',
#   'Baggage handling',
#   4.9711840650948436e-45),
#  ('Type of Travel_Personal Travel', 'Checkin service', 9.434453466716218e-07),
#  ('Type of Travel_Personal Travel',
#   'Inflight service',
#   1.9030260948645452e-31),
#  ('Type of Travel_Personal Travel', 'Cleanliness', 2.5714781945750343e-136),
#  ('Type of Travel_Personal Travel', 'satisfaction', 0.0),
#  ('Type of Travel_Personal Travel', 'Gender_Male', 0.06640012963230946),
#  ('Type of Travel_Personal Travel', 'Customer Type_disloyal Customer', 0.0),
#  ('Gender_Male', 'Class', 0.0014606703120446693),
#  ('Gender_Male', 'Inflight wifi service', 0.007230574889666334),
#  ('Gender_Male', 'Departure/Arrival time convenient', 0.044713275555195525),
#  ('Gender_Male', 'Ease of Online booking', 0.031225282566494178),
#  ('Gender_Male', 'Gate location', 0.15940519458522426),
#  ('Gender_Male', 'Food and drink', 0.019859403155602678),
#  ('Gender_Male', 'Online boarding', 2.2905591635952722e-29),
#  ('Gender_Male', 'Seat comfort', 2.464560511219716e-23),
#  ('Gender_Male', 'Inflight entertainment', 0.13081270347819088),
#  ('Gender_Male', 'On-board service', 9.755153362817055e-08),
#  ('Gender_Male', 'Leg room service', 3.281000190985411e-50),
#  ('Gender_Male', 'Baggage handling', 3.4905305920237737e-44),
#  ('Gender_Male', 'Checkin service', 0.002743413099379015),
#  ('Gender_Male', 'Inflight service', 9.451067464823345e-36),
#  ('Gender_Male', 'Cleanliness', 2.7883904307711063e-06),
#  ('Gender_Male', 'satisfaction', 8.095829340346903e-05),
#  ('Gender_Male', 'Type of Travel_Personal Travel', 0.06640012963230946),
#  ('Gender_Male', 'Customer Type_disloyal Customer', 4.582091260435383e-18),
#  ('Customer Type_disloyal Customer', 'Class', 6.3329351745467506e-260),
#  ('Customer Type_disloyal Customer',
#   'Inflight wifi service',
#   2.3033999292900185e-26),
#  ('Customer Type_disloyal Customer', 'Departure/Arrival time convenient', 0.0),
#  ('Customer Type_disloyal Customer',
#   'Ease of Online booking',
#   4.077925300595835e-49),
#  ('Customer Type_disloyal Customer', 'Gate location', 9.28588924048858e-251),
#  ('Customer Type_disloyal Customer',
#   'Food and drink',
#   1.1284421002621692e-102),
#  ('Customer Type_disloyal Customer', 'Online boarding', 0.0),
#  ('Customer Type_disloyal Customer', 'Seat comfort', 0.0),
#  ('Customer Type_disloyal Customer',
#   'Inflight entertainment',
#   4.4058878323521755e-234),
#  ('Customer Type_disloyal Customer',
#   'On-board service',
#   7.728453012144332e-109),
#  ('Customer Type_disloyal Customer',
#   'Leg room service',
#   1.0807197359750519e-100),
#  ('Customer Type_disloyal Customer',
#   'Baggage handling',
#   1.6824613018651154e-73),
#  ('Customer Type_disloyal Customer', 'Checkin service', 3.199664266266743e-17),
#  ('Customer Type_disloyal Customer',
#   'Inflight service',
#   3.1785619604175804e-53),
#  ('Customer Type_disloyal Customer', 'Cleanliness', 3.274152715269165e-182),
#  ('Customer Type_disloyal Customer', 'satisfaction', 0.0),
#  ('Customer Type_disloyal Customer', 'Type of Travel_Personal Travel', 0.0),
#  ('Customer Type_disloyal Customer', 'Gender_Male', 4.582091260435383e-18)]

# %%
chi_test_output = pd.DataFrame(result, columns = ['var1', 'var2',
                                                       'corr'])

chi_test_output = chi_test_output.pivot(index='var1', columns='var2', values='corr')
chi_test_output =  chi_test_output.rename_axis(None, axis=1)
chi_test_output =  chi_test_output.rename_axis(None, axis=0)

# Generate a mask for the upper triangle
mask = np.zeros_like(chi_test_output, dtype=bool)
mask[np.triu_indices_from(mask)] = True

# Set up the matplotlib figure
f, ax = plt.subplots(figsize=(20, 18))

# Draw the heatmap with the mask and correct aspect ratio
sns.heatmap(chi_test_output, annot = True, mask=mask, cmap="YlGnBu", center=0,
           square=True, linewidths=.5)
# Out:
# <Axes: >

# %% [markdown]
# # Binning

# %%
binning_vars = ['Age', 'Departure Delay in Minutes', 'Arrival Delay in Minutes', 'Flight Distance']

fig, (ax1, ax2, ax3, ax4) = plt.subplots(1, 4)

fig.set_figwidth(25)
fig.suptitle('Numerical columns')

ax1.set_title('Age')
ax1.set(xlabel='Years', ylabel='Freq')
ax1.hist(train_df['Age'])

ax2.set_title('Departure Delay')
ax2.set(xlabel='Minutes', ylabel='Freq')
ax2.hist(train_df['Departure Delay in Minutes'])

ax3.set_title('Arrival Delay')
ax3.set(xlabel='Minutes', ylabel='Freq')
ax3.hist(train_df['Arrival Delay in Minutes'])

ax4.set_title('Flight Distance')
ax4.set(xlabel='Km', ylabel='Freq')
ax4.hist(train_df['Flight Distance'])

plt.show()

# %%
def dist_binning(column: str):
    # 4 bins
    boundary = math.ceil((train_df[column].max()- train_df[column].min())/4)

    print(f'{column} boundary to split: ', boundary)

    bins_means = [math.ceil(train_df[(train_df[column] >= boundary*i) & (train_df[column] < boundary*(i+1))][column].mean()) for i in range(4)]
    print('Bin means: ', bins_means)

    def binnign_method(age) -> int:

        if np.isnan(age):
            return np.nan

        if age < boundary:
            return bins_means[0]

        if age < 2*boundary:
            return bins_means[1]

        if age < 3*boundary:
            return bins_means[2]

        if age < 4*boundary:
            return bins_means[3]

    print(f'{column} before binning: ', train_df[column].head(10))
    train_df[column] = train_df[column].map(binnign_method)
    validation_df[column] = validation_df[column].map(binnign_method)
    print(f'{column} After binning: ', train_df[column].head(10))

# %% [markdown]
# ### Age

# %%
dist_binning(column='Age')
# Out:
# Age boundary to split:  19
# Bin means:  [14, 29, 47, 63]
# Age before binning:  0    45
# 1    23
# 2    32
# 3    26
# 4    56
# 5    41
# 6    50
# 7    12
# 8    21
# 9    49
# Name: Age, dtype: int64
# Age After binning:  0    47.0
# 1    29.0
# 2    29.0
# 3    29.0
# 4    47.0
# 5    47.0
# 6    47.0
# 7    14.0
# 8    29.0
# 9    47.0
# Name: Age, dtype: float64

# %% [markdown]
# ### Departure Delay

# %%
dist_binning(column='Departure Delay in Minutes')
# Out:
# Departure Delay in Minutes boundary to split:  33
# Bin means:  [4, 46, 80, 113]
# Departure Delay in Minutes before binning:  0    13
# 1     0
# 2     0
# 3     0
# 4     0
# 5     7
# 6     3
# 7     0
# 8     0
# 9     0
# Name: Departure Delay in Minutes, dtype: int64
# Departure Delay in Minutes After binning:  0    4
# 1    4
# 2    4
# 3    4
# 4    4
# 5    4
# 6    4
# 7    4
# 8    4
# 9    4
# Name: Departure Delay in Minutes, dtype: int64

# %% [markdown]
# ### Arrival Delay

# %%
dist_binning(column='Arrival Delay in Minutes')
# Out:
# Arrival Delay in Minutes boundary to split:  85
# Bin means:  [9, 107, 190, 337]
# Arrival Delay in Minutes before binning:  0    10.0
# 1     0.0
# 2     2.0
# 3     0.0
# 4     0.0
# 5    14.0
# 6     0.0
# 7     0.0
# 8    15.0
# 9     7.0
# Name: Arrival Delay in Minutes, dtype: float64
# Arrival Delay in Minutes After binning:  0    9.0
# 1    9.0
# 2    9.0
# 3    9.0
# 4    9.0
# 5    9.0
# 6    9.0
# 7    9.0
# 8    9.0
# 9    9.0
# Name: Arrival Delay in Minutes, dtype: float64

# %% [markdown]
# ### Flight Distance

# %%
dist_binning(column='Flight Distance')
# Out:
# Flight Distance boundary to split:  993
# Bin means:  [496, 1425, 2442, 3481]
# Flight Distance before binning:  0    2370
# 1     784
# 2    3465
# 3     533
# 4     209
# 5     602
# 6    2719
# 7     134
# 8     250
# 9    2556
# Name: Flight Distance, dtype: int64
# Flight Distance After binning:  0    2442.0
# 1     496.0
# 2    3481.0
# 3     496.0
# 4     496.0
# 5     496.0
# 6    2442.0
# 7     496.0
# 8     496.0
# 9    2442.0
# Name: Flight Distance, dtype: float64

# %%
train_df.describe()
# Out:
#                 Age         Class  Flight Distance  Inflight wifi service  \
# count  75953.000000  76169.000000     75984.000000           76169.000000
# mean      40.021131      1.032073      1180.900861               2.727737
# std       14.030571      0.963087       951.491229               1.330110
# min       14.000000      0.000000       496.000000               0.000000
# 25%       29.000000      0.000000       496.000000               2.000000
# 50%       47.000000      1.000000       496.000000               3.000000
# 75%       47.000000      2.000000      1425.000000               4.000000
# max       63.000000      2.000000      3481.000000               5.000000
#
#        Departure/Arrival time convenient  Ease of Online booking  \
# count                       76169.000000            76169.000000
# mean                            3.059119                2.756253
# std                             1.527007                1.399678
# min                             0.000000                0.000000
# 25%                             2.000000                2.000000
# 50%                             3.000000                3.000000
# 75%                             4.000000                4.000000
# max                             5.000000                5.000000
#
#        Gate location  Food and drink  Online boarding  Seat comfort  \
# count   76169.000000    76169.000000     76169.000000  76169.000000
# mean        2.976290        3.207132         3.252596      3.445759
# std         1.277585        1.326993         1.350981      1.315003
# min         1.000000        0.000000         0.000000      1.000000
# 25%         2.000000        2.000000         2.000000      2.000000
# 50%         3.000000        3.000000         3.000000      4.000000
# 75%         4.000000        4.000000         4.000000      5.000000
# max         5.000000        5.000000         5.000000      5.000000
#
#        Inflight entertainment  On-board service  Leg room service  \
# count            76169.000000      76169.000000      76169.000000
# mean                 3.359556          3.387677          3.342029
# std                  1.334131          1.287596          1.319385
# min                  0.000000          0.000000          0.000000
# 25%                  2.000000          2.000000          2.000000
# 50%                  4.000000          4.000000          4.000000
# 75%                  4.000000          4.000000          4.000000
# max                  5.000000          5.000000          5.000000
#
#        Baggage handling  Checkin service  Inflight service   Cleanliness  \
# count      76169.000000     76169.000000       76169.00000  76169.000000
# mean           3.625793         3.303614           3.64886      3.283514
# std            1.186384         1.264214           1.17344      1.308920
# min            1.000000         1.000000           0.00000      0.000000
# 25%            3.000000         3.000000           3.00000      2.000000
# 50%            4.000000         3.000000           4.00000      3.000000
# 75%            5.000000         4.000000           5.00000      4.000000
# max            5.000000         5.000000           5.00000      5.000000
#
#        Departure Delay in Minutes  Arrival Delay in Minutes  satisfaction
# count                76169.000000              75950.000000  76169.000000
# mean                    10.647416                 11.426781      0.434928
# std                     20.225494                 15.455281      0.495751
# min                      4.000000                  9.000000      0.000000
# 25%                      4.000000                  9.000000      0.000000
# 50%                      4.000000                  9.000000      0.000000
# 75%                      4.000000                  9.000000      1.000000
# max                    113.000000                337.000000      1.000000

# %% [markdown]
# # Missing Values

# %%
# sns.heatmap(train_df.isnull(), cbar=False)
print(train_df.columns[train_df.isnull().any()])
columns = train_df.columns[train_df.isnull().any()]
train_df[columns] = train_df[columns].fillna(train_df[columns].median())
print(train_df.columns[train_df.isnull().any()])
# Out:
# Index(['Age', 'Flight Distance', 'Arrival Delay in Minutes'], dtype='object')
# Index([], dtype='object')

# %%
# sns.heatmap(validation_df.isnull(), cbar=False)
print(validation_df.columns[validation_df.isnull().any()])
columns = validation_df.columns[validation_df.isnull().any()]

#substituindo pela mediana do conjunto de teste
validation_df[columns] = validation_df[columns].fillna(train_df[columns].median())
validation_df.columns[validation_df.isnull().any()]
# Out:
# Index(['Age', 'Flight Distance', 'Departure Delay in Minutes',
#        'Arrival Delay in Minutes'],
#       dtype='object')
# Index([], dtype='object')

# %% [markdown]
# # Min Max Scaling

# %%
columns = ['Age', 'Class', 'Flight Distance', 'Inflight wifi service',
       'Departure/Arrival time convenient', 'Ease of Online booking',
       'Gate location', 'Food and drink', 'Online boarding', 'Seat comfort',
       'Inflight entertainment', 'On-board service', 'Leg room service',
       'Baggage handling', 'Checkin service', 'Inflight service',
       'Cleanliness', 'Departure Delay in Minutes', 'Arrival Delay in Minutes']

scaler = MinMaxScaler()
f_scaler=scaler.fit(train_df[columns])

# Train
train_df[columns] = f_scaler.transform(train_df[columns])

# Validation
validation_df[columns] = f_scaler.transform(validation_df[columns])

# %% [markdown]
# # OverSampling

# %%
def overSampling(x, y):
  ros = RandomOverSampler(
    sampling_strategy='auto',
    random_state=0,
  )
  return ros.fit_resample(x,y)

def printClassDistributionRate(y):
  print('total: ',len(y))
  print('satisfied: ', len(y[y['satisfaction'] == 1]), ' not satisfied: ', len(y[y['satisfaction'] != 1]))
  print('satisfied: {:.2f}%'.format(len(y[y['satisfaction'] == 1])/len(y) * 100), ' not satisfied: {:.2f}%'.format(len(y[y['satisfaction'] != 1])/len(y) * 100), '\n')

# %%
x_train_df = train_df.drop(columns='satisfaction')
y_train_df = train_df[['satisfaction']]

printClassDistributionRate(y_train_df)

x_train_df, y_train_df = overSampling(x_train_df, y_train_df )

printClassDistributionRate(y_train_df)
# Out:
# total:  76169
# satisfied:  33128  not satisfied:  43041
# satisfied: 43.49%  not satisfied: 56.51%
#
# total:  86082
# satisfied:  43041  not satisfied:  43041
# satisfied: 50.00%  not satisfied: 50.00%

# %%
x_validation_df = validation_df.drop(columns='satisfaction')
y_validation_df = validation_df[['satisfaction']]

printClassDistributionRate(y_validation_df)

x_validation_df, y_validation_df = overSampling(x_validation_df, y_validation_df )

printClassDistributionRate(y_validation_df)
# Out:
# total:  25976
# satisfied:  11256  not satisfied:  14720
# satisfied: 43.33%  not satisfied: 56.67%
#
# total:  29440
# satisfied:  14720  not satisfied:  14720
# satisfied: 50.00%  not satisfied: 50.00%

# %% [markdown]
# # Experimento com Modelos

# %%
X_train, _, y_train, _ = train_test_split(x_train_df, y_train_df, test_size=0.90, stratify=y_train_df['satisfaction'])
X_valid, _, y_valid, _ = train_test_split(x_validation_df, y_validation_df, test_size=0.50, stratify=y_validation_df['satisfaction'])


# X_train, y_train = x_train_df, y_train_df
# X_valid, y_valid = x_validation_df, y_validation_df

X_train.shape, y_train.shape
# Out:
# ((8608, 22), (8608, 1))

# %%
def plot_confusion(y_true, y_pred, title):
 disp = ConfusionMatrixDisplay.from_predictions(
 y_true,
 y_pred,
 cmap=plt.cm.Blues,
 normalize=None,
 )
 disp.ax_.set_title(title)
 plt.show()

# %%
BATCH_SIZE = 128
EPOCHS = 20000

# %% [markdown]
# ## MLP - Keras

# %%
class MPL():
  def __init__(self, in_shape, out_shape, hidden_layers, activation, dropout, optmizer, lr, regularization, patience) -> None:
    self.model = Sequential()

    self.model.add(keras.Input(shape=in_shape))
    for layer in hidden_layers:
      self.model.add(Dense(layer, activation=activation, activity_regularizer=regularizers.L2(regularization)))
      self.model.add(Dropout(dropout))


    self.model.add(Dense(out_shape, activation=activation))

    self.model.summary()

    self.early_stop_callback = keras.callbacks.EarlyStopping(monitor='val_loss', patience=patience, restore_best_weights=True, verbose=0)

    self.opt = optmizer(learning_rate=lr)

  def __del__(self):
    del self.model

  def train(self, X_train, y_train, X_validation, y_validation, batch_size, epochs):
    self.model.compile(loss="sparse_categorical_crossentropy", optimizer=self.opt, metrics=['accuracy'])
    return self.model.fit(X_train, y_train, validation_data = (X_validation, y_validation), batch_size = batch_size, epochs = epochs, shuffle = True, callbacks=[self.early_stop_callback], verbose=0)

  def evaluate(self, X, y):
    loss, accuracy = self.model.evaluate(X, y)
    print('Loss:', loss)
    print('Accuracy:', accuracy)
    return loss, accuracy

  def predict(self, x):
    return self.model.predict(x)

# %%
def plot_train_history(history):
  pd.DataFrame(history.history).plot()
  plt.xlabel("epoch")
  plt.legend(bbox_to_anchor=(1.05, 1), loc=2)
  plt.show()

# %%
def grid_search(X_t, y_t, X_v, y_v, activation_fn, hidden_layers, learning_rate, dropout, regularization):
  best_acc = 0
  best_model = None
  best_hist = None
  args = None

  for act in activation_fn:
    for hl in hidden_layers:
      for lr in learning_rate:
        for drp in dropout:
          for reg in regularization:
            print(f'PARAMETROS: F.Act.: {act}; Layers: {hl}; LR: {lr}; Dropout: {drp}; Reg: {reg}')
            tf.keras.backend.clear_session()
            model = MPL(in_shape=(22,), out_shape=2, hidden_layers=hl, activation=act, dropout=drp, optmizer=optimizers.Adam, lr=lr, regularization=reg, patience=10)
            history = model.train(X_t, y_t, X_v, y_v, batch_size=BATCH_SIZE, epochs=EPOCHS)
            loss, acc = model.evaluate(X_v, y_v)
            if acc > best_acc:
                best_acc = acc
                best_model = model
                best_hist = history
                args = f'PARAMETROS: F.Act.: {act}; Layers: {hl}; LR: {lr}; Dropout: {drp}; Reg: {reg}'
            print(f'SCORES: acc: {acc}, loss: {loss}\n')
            del model
            del history
  print(f"\n\nBest model args: {args}")
  return best_model, best_hist

X_t, y_t = np.asarray(X_train.values).astype('float32'), np.asarray(y_train.values).astype('float32')
X_v, y_v = np.asarray(X_valid.values).astype('float32'), np.asarray(y_valid.values).astype('float32')

hidden_channels = [[10, 5], [5, 10]]
actv_fns = ['sigmoid', 'relu', 'tanh','softmax']
learning_rates = [0.1, 0.01]
dropout = [0, 0.1]
regularization = [0, 0.01]

# softmax; Layers: [10, 5]; LR: 0.01; Dropout: 0; Reg: 0.01

# hidden_channels = [[10, 5]]
# actv_fns = ['softmax']
# learning_rates = [0.01]
# dropout = [0]
# regularization = [0.01]

best_model, best_hist = grid_search(X_t, y_t, X_v, y_v, actv_fns, hidden_channels, learning_rates, dropout, regularization)
plot_train_history(best_hist)
# Out:
# PARAMETROS: F.Act.: sigmoid; Layers: [10, 5]; LR: 0.1; Dropout: 0; Reg: 0
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense (Dense)               (None, 10)                230
#
#  dropout (Dropout)           (None, 10)                0
#
#  dense_1 (Dense)             (None, 5)                 55
#
#  dropout_1 (Dropout)         (None, 5)                 0
#
#  dense_2 (Dense)             (None, 2)                 12
#
# =================================================================
# Total params: 297 (1.16 KB)
# Trainable params: 297 (1.16 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________
# 460/460 [==============================] - 1s 2ms/step - loss: 0.1527 - accuracy: 0.9336
# Loss: 0.15272502601146698
# Accuracy: 0.933559775352478
# SCORES: acc: 0.933559775352478, loss: 0.15272502601146698
#
# PARAMETROS: F.Act.: sigmoid; Layers: [10, 5]; LR: 0.1; Dropout: 0; Reg: 0.01
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense (Dense)               (None, 10)                230
#
#  dropout (Dropout)           (None, 10)                0
#
#  dense_1 (Dense)             (None, 5)                 55
#
#  dropout_1 (Dropout)         (None, 5)                 0
#
#  dense_2 (Dense)             (None, 2)                 12
#
# =================================================================
# Total params: 297 (1.16 KB)
# Trainable params: 297 (1.16 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________
# 460/460 [==============================] - 1s 1ms/step - loss: 0.1715 - accuracy: 0.9344
# Loss: 0.1714966595172882
# Accuracy: 0.934374988079071
# SCORES: acc: 0.934374988079071, loss: 0.1714966595172882
#
# PARAMETROS: F.Act.: sigmoid; Layers: [10, 5]; LR: 0.1; Dropout: 0.1; Reg: 0
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense (Dense)               (None, 10)                230
#
#  dropout (Dropout)           (None, 10)                0
#
#  dense_1 (Dense)             (None, 5)                 55
#
#  dropout_1 (Dropout)         (None, 5)                 0
#
#  dense_2 (Dense)             (None, 2)                 12
#
# =================================================================
# Total params: 297 (1.16 KB)
# Trainable params: 297 (1.16 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________
# 460/460 [==============================] - 1s 1ms/step - loss: 0.1607 - accuracy: 0.9346
# Loss: 0.1606520265340805
# Accuracy: 0.9345787763595581
# SCORES: acc: 0.9345787763595581, loss: 0.1606520265340805
#
# PARAMETROS: F.Act.: sigmoid; Layers: [10, 5]; LR: 0.1; Dropout: 0.1; Reg: 0.01
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense (Dense)               (None, 10)                230
#
#  dropout (Dropout)           (None, 10)                0
#
#  dense_1 (Dense)             (None, 5)                 55
#
#  dropout_1 (Dropout)         (None, 5)                 0
#
#  dense_2 (Dense)             (None, 2)                 12
#
# =================================================================
# Total params: 297 (1.16 KB)
# Trainable params: 297 (1.16 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________
# 460/460 [==============================] - 1s 1ms/step - loss: 0.2349 - accuracy: 0.9019
# Loss: 0.23489412665367126
# Accuracy: 0.9019021987915039
# SCORES: acc: 0.9019021987915039, loss: 0.23489412665367126
#
# PARAMETROS: F.Act.: sigmoid; Layers: [10, 5]; LR: 0.01; Dropout: 0; Reg: 0
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense (Dense)               (None, 10)                230
#
#  dropout (Dropout)           (None, 10)                0
#
#  dense_1 (Dense)             (None, 5)                 55
#
#  dropout_1 (Dropout)         (None, 5)                 0
#
#  dense_2 (Dense)             (None, 2)                 12
#
# =================================================================
# Total params: 297 (1.16 KB)
# Trainable params: 297 (1.16 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________
# 460/460 [==============================] - 1s 2ms/step - loss: 0.1560 - accuracy: 0.9328
# Loss: 0.156021386384964
# Accuracy: 0.932812511920929
# SCORES: acc: 0.932812511920929, loss: 0.156021386384964
#
# PARAMETROS: F.Act.: sigmoid; Layers: [10, 5]; LR: 0.01; Dropout: 0; Reg: 0.01
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense (Dense)               (None, 10)                230
#
#  dropout (Dropout)           (None, 10)                0
#
#  dense_1 (Dense)             (None, 5)                 55
#
#  dropout_1 (Dropout)         (None, 5)                 0
#
#  dense_2 (Dense)             (None, 2)                 12
#
# =================================================================
# Total params: 297 (1.16 KB)
# Trainable params: 297 (1.16 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________
# 460/460 [==============================] - 3s 6ms/step - loss: 0.1716 - accuracy: 0.9299
# Loss: 0.17162106931209564
# Accuracy: 0.9298912882804871
# SCORES: acc: 0.9298912882804871, loss: 0.17162106931209564
#
# PARAMETROS: F.Act.: sigmoid; Layers: [10, 5]; LR: 0.01; Dropout: 0.1; Reg: 0
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense (Dense)               (None, 10)                230
#
#  dropout (Dropout)           (None, 10)                0
#
#  dense_1 (Dense)             (None, 5)                 55
#
#  dropout_1 (Dropout)         (None, 5)                 0
#
#  dense_2 (Dense)             (None, 2)                 12
#
# =================================================================
# Total params: 297 (1.16 KB)
# Trainable params: 297 (1.16 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________
# 460/460 [==============================] - 1s 1ms/step - loss: 0.1572 - accuracy: 0.9350
# Loss: 0.15721023082733154
# Accuracy: 0.934986412525177
# SCORES: acc: 0.934986412525177, loss: 0.15721023082733154
#
# PARAMETROS: F.Act.: sigmoid; Layers: [10, 5]; LR: 0.01; Dropout: 0.1; Reg: 0.01
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense (Dense)               (None, 10)                230
#
#  dropout (Dropout)           (None, 10)                0
#
#  dense_1 (Dense)             (None, 5)                 55
#
#  dropout_1 (Dropout)         (None, 5)                 0
#
#  dense_2 (Dense)             (None, 2)                 12
#
# =================================================================
# Total params: 297 (1.16 KB)
# Trainable params: 297 (1.16 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________
# 460/460 [==============================] - 1s 1ms/step - loss: 0.1719 - accuracy: 0.9307
# Loss: 0.17185178399085999
# Accuracy: 0.9307065010070801
# SCORES: acc: 0.9307065010070801, loss: 0.17185178399085999
#
# PARAMETROS: F.Act.: sigmoid; Layers: [5, 10]; LR: 0.1; Dropout: 0; Reg: 0
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense (Dense)               (None, 5)                 115
#
#  dropout (Dropout)           (None, 5)                 0
#
#  dense_1 (Dense)             (None, 10)                60
#
#  dropout_1 (Dropout)         (None, 10)                0
#
#  dense_2 (Dense)             (None, 2)                 22
#
# =================================================================
# Total params: 197 (788.00 Byte)
# Trainable params: 197 (788.00 Byte)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________
# 460/460 [==============================] - 1s 1ms/step - loss: 0.1731 - accuracy: 0.9284
# Loss: 0.17309889197349548
# Accuracy: 0.9283967614173889
# SCORES: acc: 0.9283967614173889, loss: 0.17309889197349548
#
# PARAMETROS: F.Act.: sigmoid; Layers: [5, 10]; LR: 0.1; Dropout: 0; Reg: 0.01
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense (Dense)               (None, 5)                 115
#
#  dropout (Dropout)           (None, 5)                 0
#
#  dense_1 (Dense)             (None, 10)                60
#
#  dropout_1 (Dropout)         (None, 10)                0
#
#  dense_2 (Dense)             (None, 2)                 22
#
# =================================================================
# Total params: 197 (788.00 Byte)
# Trainable params: 197 (788.00 Byte)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________
# 460/460 [==============================] - 1s 1ms/step - loss: 0.1684 - accuracy: 0.9353
# Loss: 0.16844964027404785
# Accuracy: 0.935326099395752
# SCORES: acc: 0.935326099395752, loss: 0.16844964027404785
#
# PARAMETROS: F.Act.: sigmoid; Layers: [5, 10]; LR: 0.1; Dropout: 0.1; Reg: 0
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense (Dense)               (None, 5)                 115
#
#  dropout (Dropout)           (None, 5)                 0
#
#  dense_1 (Dense)             (None, 10)                60
#
#  dropout_1 (Dropout)         (None, 10)                0
#
#  dense_2 (Dense)             (None, 2)                 22
#
# =================================================================
# Total params: 197 (788.00 Byte)
# Trainable params: 197 (788.00 Byte)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________
# 460/460 [==============================] - 1s 1ms/step - loss: 0.1706 - accuracy: 0.9272
# Loss: 0.17055918276309967
# Accuracy: 0.927173912525177
# SCORES: acc: 0.927173912525177, loss: 0.17055918276309967
#
# PARAMETROS: F.Act.: sigmoid; Layers: [5, 10]; LR: 0.1; Dropout: 0.1; Reg: 0.01
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense (Dense)               (None, 5)                 115
#
#  dropout (Dropout)           (None, 5)                 0
#
#  dense_1 (Dense)             (None, 10)                60
#
#  dropout_1 (Dropout)         (None, 10)                0
#
#  dense_2 (Dense)             (None, 2)                 22
#
# =================================================================
# Total params: 197 (788.00 Byte)
# Trainable params: 197 (788.00 Byte)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________
# 460/460 [==============================] - 1s 2ms/step - loss: 0.2441 - accuracy: 0.8904
# Loss: 0.24406537413597107
# Accuracy: 0.8904212117195129
# SCORES: acc: 0.8904212117195129, loss: 0.24406537413597107
#
# PARAMETROS: F.Act.: sigmoid; Layers: [5, 10]; LR: 0.01; Dropout: 0; Reg: 0
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense (Dense)               (None, 5)                 115
#
#  dropout (Dropout)           (None, 5)                 0
#
#  dense_1 (Dense)             (None, 10)                60
#
#  dropout_1 (Dropout)         (None, 10)                0
#
#  dense_2 (Dense)             (None, 2)                 22
#
# =================================================================
# Total params: 197 (788.00 Byte)
# Trainable params: 197 (788.00 Byte)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________
# 460/460 [==============================] - 1s 1ms/step - loss: 0.1744 - accuracy: 0.9274
# Loss: 0.17439132928848267
# Accuracy: 0.927445650100708
# SCORES: acc: 0.927445650100708, loss: 0.17439132928848267
#
# PARAMETROS: F.Act.: sigmoid; Layers: [5, 10]; LR: 0.01; Dropout: 0; Reg: 0.01
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense (Dense)               (None, 5)                 115
#
#  dropout (Dropout)           (None, 5)                 0
#
#  dense_1 (Dense)             (None, 10)                60
#
#  dropout_1 (Dropout)         (None, 10)                0
#
#  dense_2 (Dense)             (None, 2)                 22
#
# =================================================================
# Total params: 197 (788.00 Byte)
# Trainable params: 197 (788.00 Byte)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________
# 460/460 [==============================] - 1s 2ms/step - loss: 0.1775 - accuracy: 0.9296
# Loss: 0.17753177881240845
# Accuracy: 0.929619550704956
# SCORES: acc: 0.929619550704956, loss: 0.17753177881240845
#
# PARAMETROS: F.Act.: sigmoid; Layers: [5, 10]; LR: 0.01; Dropout: 0.1; Reg: 0
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense (Dense)               (None, 5)                 115
#
#  dropout (Dropout)           (None, 5)                 0
#
#  dense_1 (Dense)             (None, 10)                60
#
#  dropout_1 (Dropout)         (None, 10)                0
#
#  dense_2 (Dense)             (None, 2)                 22
#
# =================================================================
# Total params: 197 (788.00 Byte)
# Trainable params: 197 (788.00 Byte)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________
# 460/460 [==============================] - 1s 2ms/step - loss: 0.1752 - accuracy: 0.9263
# Loss: 0.17519399523735046
# Accuracy: 0.92629075050354
# SCORES: acc: 0.92629075050354, loss: 0.17519399523735046
#
# PARAMETROS: F.Act.: sigmoid; Layers: [5, 10]; LR: 0.01; Dropout: 0.1; Reg: 0.01
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense (Dense)               (None, 5)                 115
#
#  dropout (Dropout)           (None, 5)                 0
#
#  dense_1 (Dense)             (None, 10)                60
#
#  dropout_1 (Dropout)         (None, 10)                0
#
#  dense_2 (Dense)             (None, 2)                 22
#
# =================================================================
# Total params: 197 (788.00 Byte)
# Trainable params: 197 (788.00 Byte)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________
# 460/460 [==============================] - 1s 2ms/step - loss: 0.1971 - accuracy: 0.9202
# Loss: 0.19711168110370636
# Accuracy: 0.92017662525177
# SCORES: acc: 0.92017662525177, loss: 0.19711168110370636
#
# PARAMETROS: F.Act.: relu; Layers: [10, 5]; LR: 0.1; Dropout: 0; Reg: 0
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense (Dense)               (None, 10)                230
#
#  dropout (Dropout)           (None, 10)                0
#
#  dense_1 (Dense)             (None, 5)                 55
#
#  dropout_1 (Dropout)         (None, 5)                 0
#
#  dense_2 (Dense)             (None, 2)                 12
#
# =================================================================
# Total params: 297 (1.16 KB)
# Trainable params: 297 (1.16 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________
# 460/460 [==============================] - 1s 2ms/step - loss: 0.6931 - accuracy: 0.5000
# Loss: 0.6931459307670593
# Accuracy: 0.5
# SCORES: acc: 0.5, loss: 0.6931459307670593
#
# PARAMETROS: F.Act.: relu; Layers: [10, 5]; LR: 0.1; Dropout: 0; Reg: 0.01
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense (Dense)               (None, 10)                230
#
#  dropout (Dropout)           (None, 10)                0
#
#  dense_1 (Dense)             (None, 5)                 55
#
#  dropout_1 (Dropout)         (None, 5)                 0
#
#  dense_2 (Dense)             (None, 2)                 12
#
# =================================================================
# Total params: 297 (1.16 KB)
# Trainable params: 297 (1.16 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________
# 460/460 [==============================] - 1s 2ms/step - loss: 0.6931 - accuracy: 0.5000
# Loss: 0.6931459307670593
# Accuracy: 0.5
# SCORES: acc: 0.5, loss: 0.6931459307670593
#
# PARAMETROS: F.Act.: relu; Layers: [10, 5]; LR: 0.1; Dropout: 0.1; Reg: 0
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense (Dense)               (None, 10)                230
#
#  dropout (Dropout)           (None, 10)                0
#
#  dense_1 (Dense)             (None, 5)                 55
#
#  dropout_1 (Dropout)         (None, 5)                 0
#
#  dense_2 (Dense)             (None, 2)                 12
#
# =================================================================
# Total params: 297 (1.16 KB)
# Trainable params: 297 (1.16 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________
# 460/460 [==============================] - 1s 2ms/step - loss: 0.6931 - accuracy: 0.5000
# Loss: 0.6931459307670593
# Accuracy: 0.5
# SCORES: acc: 0.5, loss: 0.6931459307670593
#
# PARAMETROS: F.Act.: relu; Layers: [10, 5]; LR: 0.1; Dropout: 0.1; Reg: 0.01
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense (Dense)               (None, 10)                230
#
#  dropout (Dropout)           (None, 10)                0
#
#  dense_1 (Dense)             (None, 5)                 55
#
#  dropout_1 (Dropout)         (None, 5)                 0
#
#  dense_2 (Dense)             (None, 2)                 12
#
# =================================================================
# Total params: 297 (1.16 KB)
# Trainable params: 297 (1.16 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________
# 460/460 [==============================] - 1s 1ms/step - loss: 0.6931 - accuracy: 0.5000
# Loss: 0.6931459307670593
# Accuracy: 0.5
# SCORES: acc: 0.5, loss: 0.6931459307670593
#
# PARAMETROS: F.Act.: relu; Layers: [10, 5]; LR: 0.01; Dropout: 0; Reg: 0
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense (Dense)               (None, 10)                230
#
#  dropout (Dropout)           (None, 10)                0
#
#  dense_1 (Dense)             (None, 5)                 55
#
#  dropout_1 (Dropout)         (None, 5)                 0
#
#  dense_2 (Dense)             (None, 2)                 12
#
# =================================================================
# Total params: 297 (1.16 KB)
# Trainable params: 297 (1.16 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________
# 460/460 [==============================] - 1s 2ms/step - loss: 0.2616 - accuracy: 0.8938
# Loss: 0.2616353929042816
# Accuracy: 0.8938179612159729
# SCORES: acc: 0.8938179612159729, loss: 0.2616353929042816
#
# PARAMETROS: F.Act.: relu; Layers: [10, 5]; LR: 0.01; Dropout: 0; Reg: 0.01
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense (Dense)               (None, 10)                230
#
#  dropout (Dropout)           (None, 10)                0
#
#  dense_1 (Dense)             (None, 5)                 55
#
#  dropout_1 (Dropout)         (None, 5)                 0
#
#  dense_2 (Dense)             (None, 2)                 12
#
# =================================================================
# Total params: 297 (1.16 KB)
# Trainable params: 297 (1.16 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________
# 460/460 [==============================] - 1s 2ms/step - loss: 0.6931 - accuracy: 0.5000
# Loss: 0.693146288394928
# Accuracy: 0.5
# SCORES: acc: 0.5, loss: 0.693146288394928
#
# PARAMETROS: F.Act.: relu; Layers: [10, 5]; LR: 0.01; Dropout: 0.1; Reg: 0
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense (Dense)               (None, 10)                230
#
#  dropout (Dropout)           (None, 10)                0
#
#  dense_1 (Dense)             (None, 5)                 55
#
#  dropout_1 (Dropout)         (None, 5)                 0
#
#  dense_2 (Dense)             (None, 2)                 12
#
# =================================================================
# Total params: 297 (1.16 KB)
# Trainable params: 297 (1.16 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________
# 460/460 [==============================] - 1s 2ms/step - loss: 0.6931 - accuracy: 0.5000
# Loss: 0.6931459307670593
# Accuracy: 0.5
# SCORES: acc: 0.5, loss: 0.6931459307670593
#
# PARAMETROS: F.Act.: relu; Layers: [10, 5]; LR: 0.01; Dropout: 0.1; Reg: 0.01
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense (Dense)               (None, 10)                230
#
#  dropout (Dropout)           (None, 10)                0
#
#  dense_1 (Dense)             (None, 5)                 55
#
#  dropout_1 (Dropout)         (None, 5)                 0
#
#  dense_2 (Dense)             (None, 2)                 12
#
# =================================================================
# Total params: 297 (1.16 KB)
# Trainable params: 297 (1.16 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________
# 460/460 [==============================] - 1s 2ms/step - loss: 0.6931 - accuracy: 0.5000
# Loss: 0.6931463479995728
# Accuracy: 0.5
# SCORES: acc: 0.5, loss: 0.6931463479995728
#
# PARAMETROS: F.Act.: relu; Layers: [5, 10]; LR: 0.1; Dropout: 0; Reg: 0
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense (Dense)               (None, 5)                 115
#
#  dropout (Dropout)           (None, 5)                 0
#
#  dense_1 (Dense)             (None, 10)                60
#
#  dropout_1 (Dropout)         (None, 10)                0
#
#  dense_2 (Dense)             (None, 2)                 22
#
# =================================================================
# Total params: 197 (788.00 Byte)
# Trainable params: 197 (788.00 Byte)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________
# 460/460 [==============================] - 1s 2ms/step - loss: 0.6931 - accuracy: 0.5000
# Loss: 0.6931459307670593
# Accuracy: 0.5
# SCORES: acc: 0.5, loss: 0.6931459307670593
#
# PARAMETROS: F.Act.: relu; Layers: [5, 10]; LR: 0.1; Dropout: 0; Reg: 0.01
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense (Dense)               (None, 5)                 115
#
#  dropout (Dropout)           (None, 5)                 0
#
#  dense_1 (Dense)             (None, 10)                60
#
#  dropout_1 (Dropout)         (None, 10)                0
#
#  dense_2 (Dense)             (None, 2)                 22
#
# =================================================================
# Total params: 197 (788.00 Byte)
# Trainable params: 197 (788.00 Byte)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________
# 460/460 [==============================] - 1s 2ms/step - loss: 0.5666 - accuracy: 0.5000
# Loss: 0.5665611624717712
# Accuracy: 0.5
# SCORES: acc: 0.5, loss: 0.5665611624717712
#
# PARAMETROS: F.Act.: relu; Layers: [5, 10]; LR: 0.1; Dropout: 0.1; Reg: 0
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense (Dense)               (None, 5)                 115
#
#  dropout (Dropout)           (None, 5)                 0
#
#  dense_1 (Dense)             (None, 10)                60
#
#  dropout_1 (Dropout)         (None, 10)                0
#
#  dense_2 (Dense)             (None, 2)                 22
#
# =================================================================
# Total params: 197 (788.00 Byte)
# Trainable params: 197 (788.00 Byte)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________
# 460/460 [==============================] - 1s 2ms/step - loss: 0.6931 - accuracy: 0.5000
# Loss: 0.6931459307670593
# Accuracy: 0.5
# SCORES: acc: 0.5, loss: 0.6931459307670593
#
# PARAMETROS: F.Act.: relu; Layers: [5, 10]; LR: 0.1; Dropout: 0.1; Reg: 0.01
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense (Dense)               (None, 5)                 115
#
#  dropout (Dropout)           (None, 5)                 0
#
#  dense_1 (Dense)             (None, 10)                60
#
#  dropout_1 (Dropout)         (None, 10)                0
#
#  dense_2 (Dense)             (None, 2)                 22
#
# =================================================================
# Total params: 197 (788.00 Byte)
# Trainable params: 197 (788.00 Byte)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________
# 460/460 [==============================] - 1s 2ms/step - loss: 0.6931 - accuracy: 0.5000
# Loss: 0.6931461095809937
# Accuracy: 0.5
# SCORES: acc: 0.5, loss: 0.6931461095809937
#
# PARAMETROS: F.Act.: relu; Layers: [5, 10]; LR: 0.01; Dropout: 0; Reg: 0
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense (Dense)               (None, 5)                 115
#
#  dropout (Dropout)           (None, 5)                 0
#
#  dense_1 (Dense)             (None, 10)                60
#
#  dropout_1 (Dropout)         (None, 10)                0
#
#  dense_2 (Dense)             (None, 2)                 22
#
# =================================================================
# Total params: 197 (788.00 Byte)
# Trainable params: 197 (788.00 Byte)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________
# 460/460 [==============================] - 1s 2ms/step - loss: 0.3184 - accuracy: 0.8662
# Loss: 0.3183717429637909
# Accuracy: 0.8662363886833191
# SCORES: acc: 0.8662363886833191, loss: 0.3183717429637909
#
# PARAMETROS: F.Act.: relu; Layers: [5, 10]; LR: 0.01; Dropout: 0; Reg: 0.01
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense (Dense)               (None, 5)                 115
#
#  dropout (Dropout)           (None, 5)                 0
#
#  dense_1 (Dense)             (None, 10)                60
#
#  dropout_1 (Dropout)         (None, 10)                0
#
#  dense_2 (Dense)             (None, 2)                 22
#
# =================================================================
# Total params: 197 (788.00 Byte)
# Trainable params: 197 (788.00 Byte)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________
# 460/460 [==============================] - 1s 2ms/step - loss: 0.6931 - accuracy: 0.5000
# Loss: 0.693146288394928
# Accuracy: 0.5
# SCORES: acc: 0.5, loss: 0.693146288394928
#
# PARAMETROS: F.Act.: relu; Layers: [5, 10]; LR: 0.01; Dropout: 0.1; Reg: 0
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense (Dense)               (None, 5)                 115
#
#  dropout (Dropout)           (None, 5)                 0
#
#  dense_1 (Dense)             (None, 10)                60
#
#  dropout_1 (Dropout)         (None, 10)                0
#
#  dense_2 (Dense)             (None, 2)                 22
#
# =================================================================
# Total params: 197 (788.00 Byte)
# Trainable params: 197 (788.00 Byte)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________
# 460/460 [==============================] - 1s 2ms/step - loss: 0.6931 - accuracy: 0.5000
# Loss: 0.6931459307670593
# Accuracy: 0.5
# SCORES: acc: 0.5, loss: 0.6931459307670593
#
# PARAMETROS: F.Act.: relu; Layers: [5, 10]; LR: 0.01; Dropout: 0.1; Reg: 0.01
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense (Dense)               (None, 5)                 115
#
#  dropout (Dropout)           (None, 5)                 0
#
#  dense_1 (Dense)             (None, 10)                60
#
#  dropout_1 (Dropout)         (None, 10)                0
#
#  dense_2 (Dense)             (None, 2)                 22
#
# =================================================================
# Total params: 197 (788.00 Byte)
# Trainable params: 197 (788.00 Byte)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________
# 460/460 [==============================] - 1s 2ms/step - loss: 0.6931 - accuracy: 0.5000
# Loss: 0.693146288394928
# Accuracy: 0.5
# SCORES: acc: 0.5, loss: 0.693146288394928
#
# PARAMETROS: F.Act.: tanh; Layers: [10, 5]; LR: 0.1; Dropout: 0; Reg: 0
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense (Dense)               (None, 10)                230
#
#  dropout (Dropout)           (None, 10)                0
#
#  dense_1 (Dense)             (None, 5)                 55
#
#  dropout_1 (Dropout)         (None, 5)                 0
#
#  dense_2 (Dense)             (None, 2)                 12
#
# =================================================================
# Total params: 297 (1.16 KB)
# Trainable params: 297 (1.16 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________
# 460/460 [==============================] - 1s 2ms/step - loss: 0.6931 - accuracy: 0.5000
# Loss: 0.6931459307670593
# Accuracy: 0.5
# SCORES: acc: 0.5, loss: 0.6931459307670593
#
# PARAMETROS: F.Act.: tanh; Layers: [10, 5]; LR: 0.1; Dropout: 0; Reg: 0.01
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense (Dense)               (None, 10)                230
#
#  dropout (Dropout)           (None, 10)                0
#
#  dense_1 (Dense)             (None, 5)                 55
#
#  dropout_1 (Dropout)         (None, 5)                 0
#
#  dense_2 (Dense)             (None, 2)                 12
#
# =================================================================
# Total params: 297 (1.16 KB)
# Trainable params: 297 (1.16 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________
# 460/460 [==============================] - 1s 2ms/step - loss: 0.7334 - accuracy: 0.5000
# Loss: 0.7334039807319641
# Accuracy: 0.5
# SCORES: acc: 0.5, loss: 0.7334039807319641
#
# PARAMETROS: F.Act.: tanh; Layers: [10, 5]; LR: 0.1; Dropout: 0.1; Reg: 0
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense (Dense)               (None, 10)                230
#
#  dropout (Dropout)           (None, 10)                0
#
#  dense_1 (Dense)             (None, 5)                 55
#
#  dropout_1 (Dropout)         (None, 5)                 0
#
#  dense_2 (Dense)             (None, 2)                 12
#
# =================================================================
# Total params: 297 (1.16 KB)
# Trainable params: 297 (1.16 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________
# 460/460 [==============================] - 1s 2ms/step - loss: 0.6931 - accuracy: 0.5000
# Loss: 0.6931459307670593
# Accuracy: 0.5
# ...
#  dense_2 (Dense)             (None, 2)                 12
#
# =================================================================
# Total params: 297 (1.16 KB)
# Trainable params: 297 (1.16 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________
# 460/460 [==============================] - 1s 3ms/step - loss: 0.1594 - accuracy: 0.9323
# Loss: 0.1594037115573883
# Accuracy: 0.9322690367698669
# SCORES: acc: 0.9322690367698669, loss: 0.1594037115573883
#
# PARAMETROS: F.Act.: softmax; Layers: [10, 5]; LR: 0.01; Dropout: 0; Reg: 0.01
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense (Dense)               (None, 10)                230
#
#  dropout (Dropout)           (None, 10)                0
#
#  dense_1 (Dense)             (None, 5)                 55
#
#  dropout_1 (Dropout)         (None, 5)                 0
#
#  dense_2 (Dense)             (None, 2)                 12
#
# =================================================================
# Total params: 297 (1.16 KB)
# Trainable params: 297 (1.16 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________
# 460/460 [==============================] - 1s 2ms/step - loss: 0.1741 - accuracy: 0.9308
# Loss: 0.17409567534923553
# Accuracy: 0.930774450302124
# SCORES: acc: 0.930774450302124, loss: 0.17409567534923553
#
# PARAMETROS: F.Act.: softmax; Layers: [10, 5]; LR: 0.01; Dropout: 0.1; Reg: 0
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense (Dense)               (None, 10)                230
#
#  dropout (Dropout)           (None, 10)                0
#
#  dense_1 (Dense)             (None, 5)                 55
#
#  dropout_1 (Dropout)         (None, 5)                 0
#
#  dense_2 (Dense)             (None, 2)                 12
#
# =================================================================
# Total params: 297 (1.16 KB)
# Trainable params: 297 (1.16 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________
# 460/460 [==============================] - 1s 2ms/step - loss: 0.1554 - accuracy: 0.9321
# Loss: 0.15541213750839233
# Accuracy: 0.932133138179779
# SCORES: acc: 0.932133138179779, loss: 0.15541213750839233
#
# PARAMETROS: F.Act.: softmax; Layers: [10, 5]; LR: 0.01; Dropout: 0.1; Reg: 0.01
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense (Dense)               (None, 10)                230
#
#  dropout (Dropout)           (None, 10)                0
#
#  dense_1 (Dense)             (None, 5)                 55
#
#  dropout_1 (Dropout)         (None, 5)                 0
#
#  dense_2 (Dense)             (None, 2)                 12
#
# =================================================================
# Total params: 297 (1.16 KB)
# Trainable params: 297 (1.16 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________
# 460/460 [==============================] - 1s 2ms/step - loss: 0.1589 - accuracy: 0.9374
# Loss: 0.15887874364852905
# Accuracy: 0.9373641014099121
# SCORES: acc: 0.9373641014099121, loss: 0.15887874364852905
#
# PARAMETROS: F.Act.: softmax; Layers: [5, 10]; LR: 0.1; Dropout: 0; Reg: 0
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense (Dense)               (None, 5)                 115
#
#  dropout (Dropout)           (None, 5)                 0
#
#  dense_1 (Dense)             (None, 10)                60
#
#  dropout_1 (Dropout)         (None, 10)                0
#
#  dense_2 (Dense)             (None, 2)                 22
#
# =================================================================
# Total params: 197 (788.00 Byte)
# Trainable params: 197 (788.00 Byte)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________
# 460/460 [==============================] - 1s 2ms/step - loss: 0.1749 - accuracy: 0.9233
# Loss: 0.17491938173770905
# Accuracy: 0.923301637172699
# SCORES: acc: 0.923301637172699, loss: 0.17491938173770905
#
# PARAMETROS: F.Act.: softmax; Layers: [5, 10]; LR: 0.1; Dropout: 0; Reg: 0.01
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense (Dense)               (None, 5)                 115
#
#  dropout (Dropout)           (None, 5)                 0
#
#  dense_1 (Dense)             (None, 10)                60
#
#  dropout_1 (Dropout)         (None, 10)                0
#
#  dense_2 (Dense)             (None, 2)                 22
#
# =================================================================
# Total params: 197 (788.00 Byte)
# Trainable params: 197 (788.00 Byte)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________
# 460/460 [==============================] - 1s 3ms/step - loss: 0.2568 - accuracy: 0.9039
# Loss: 0.25679874420166016
# Accuracy: 0.9039402008056641
# SCORES: acc: 0.9039402008056641, loss: 0.25679874420166016
#
# PARAMETROS: F.Act.: softmax; Layers: [5, 10]; LR: 0.1; Dropout: 0.1; Reg: 0
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense (Dense)               (None, 5)                 115
#
#  dropout (Dropout)           (None, 5)                 0
#
#  dense_1 (Dense)             (None, 10)                60
#
#  dropout_1 (Dropout)         (None, 10)                0
#
#  dense_2 (Dense)             (None, 2)                 22
#
# =================================================================
# Total params: 197 (788.00 Byte)
# Trainable params: 197 (788.00 Byte)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________
# 460/460 [==============================] - 1s 2ms/step - loss: 0.1930 - accuracy: 0.9192
# Loss: 0.19296766817569733
# Accuracy: 0.9191576242446899
# SCORES: acc: 0.9191576242446899, loss: 0.19296766817569733
#
# PARAMETROS: F.Act.: softmax; Layers: [5, 10]; LR: 0.1; Dropout: 0.1; Reg: 0.01
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense (Dense)               (None, 5)                 115
#
#  dropout (Dropout)           (None, 5)                 0
#
#  dense_1 (Dense)             (None, 10)                60
#
#  dropout_1 (Dropout)         (None, 10)                0
#
#  dense_2 (Dense)             (None, 2)                 22
#
# =================================================================
# Total params: 197 (788.00 Byte)
# Trainable params: 197 (788.00 Byte)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________
# 460/460 [==============================] - 1s 2ms/step - loss: 0.1850 - accuracy: 0.9281
# Loss: 0.18496254086494446
# Accuracy: 0.9281250238418579
# SCORES: acc: 0.9281250238418579, loss: 0.18496254086494446
#
# PARAMETROS: F.Act.: softmax; Layers: [5, 10]; LR: 0.01; Dropout: 0; Reg: 0
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense (Dense)               (None, 5)                 115
#
#  dropout (Dropout)           (None, 5)                 0
#
#  dense_1 (Dense)             (None, 10)                60
#
#  dropout_1 (Dropout)         (None, 10)                0
#
#  dense_2 (Dense)             (None, 2)                 22
#
# =================================================================
# Total params: 197 (788.00 Byte)
# Trainable params: 197 (788.00 Byte)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________
# 460/460 [==============================] - 1s 2ms/step - loss: 0.1678 - accuracy: 0.9257
# Loss: 0.1678193360567093
# Accuracy: 0.9256793260574341
# SCORES: acc: 0.9256793260574341, loss: 0.1678193360567093
#
# PARAMETROS: F.Act.: softmax; Layers: [5, 10]; LR: 0.01; Dropout: 0; Reg: 0.01
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense (Dense)               (None, 5)                 115
#
#  dropout (Dropout)           (None, 5)                 0
#
#  dense_1 (Dense)             (None, 10)                60
#
#  dropout_1 (Dropout)         (None, 10)                0
#
#  dense_2 (Dense)             (None, 2)                 22
#
# =================================================================
# Total params: 197 (788.00 Byte)
# Trainable params: 197 (788.00 Byte)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________
# 460/460 [==============================] - 1s 2ms/step - loss: 0.1741 - accuracy: 0.9283
# Loss: 0.17405541241168976
# Accuracy: 0.928260862827301
# SCORES: acc: 0.928260862827301, loss: 0.17405541241168976
#
# PARAMETROS: F.Act.: softmax; Layers: [5, 10]; LR: 0.01; Dropout: 0.1; Reg: 0
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense (Dense)               (None, 5)                 115
#
#  dropout (Dropout)           (None, 5)                 0
#
#  dense_1 (Dense)             (None, 10)                60
#
#  dropout_1 (Dropout)         (None, 10)                0
#
#  dense_2 (Dense)             (None, 2)                 22
#
# =================================================================
# Total params: 197 (788.00 Byte)
# Trainable params: 197 (788.00 Byte)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________
# 460/460 [==============================] - 1s 2ms/step - loss: 0.2045 - accuracy: 0.9198
# Loss: 0.2045256793498993
# Accuracy: 0.9198369383811951
# SCORES: acc: 0.9198369383811951, loss: 0.2045256793498993
#
# PARAMETROS: F.Act.: softmax; Layers: [5, 10]; LR: 0.01; Dropout: 0.1; Reg: 0.01
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense (Dense)               (None, 5)                 115
#
#  dropout (Dropout)           (None, 5)                 0
#
#  dense_1 (Dense)             (None, 10)                60
#
#  dropout_1 (Dropout)         (None, 10)                0
#
#  dense_2 (Dense)             (None, 2)                 22
#
# =================================================================
# Total params: 197 (788.00 Byte)
# Trainable params: 197 (788.00 Byte)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________
# 460/460 [==============================] - 1s 2ms/step - loss: 0.2199 - accuracy: 0.9181
# Loss: 0.21991682052612305
# Accuracy: 0.9181385636329651
# SCORES: acc: 0.9181385636329651, loss: 0.21991682052612305
#
#
#
# Best model args: PARAMETROS: F.Act.: softmax; Layers: [10, 5]; LR: 0.01; Dropout: 0.1; Reg: 0.01

# %%
best_model.evaluate(X_v, y_v)
# Out:
# 460/460 [==============================] - 1s 2ms/step - loss: 0.1589 - accuracy: 0.9374
# Loss: 0.15887874364852905
# Accuracy: 0.9373641014099121
# (0.15887874364852905, 0.9373641014099121)

# %%
# X_t, y_t = np.asarray(X_train.values).astype('float32'), np.asarray(y_train.values).astype('float32')
# X_v, y_v = np.asarray(X_valid.values).astype('float32'), np.asarray(y_valid.values).astype('float32')

# tf.keras.backend.clear_session()
# history = best_model.train(X_t, y_t, X_v, y_v, batch_size=BATCH_SIZE, epochs=EPOCHS)

# %%
# plot_train_history(history)

# %%
# best_model.evaluate(X_v, y_v)

# %%
# y_pred = best_model.predict(X_v)
# y_pred
# plot_confusion(y_v, y_pred, 'Best Model')

# %% [markdown]
# ## MLP - Torch

# %%
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
device
# Out:
# device(type='cpu')

# %%
def train(model, optimizer, loss_fn, train_dl, valid_dl, epochs, plot_loss = False):
  best_loss = np.infty

  model = model.to(device)
  best_model = model
  model.train()
  train_losses = []
  valid_losses = []

  for epoch in range(epochs):

    acc_loss = []

    for X, y in iter(train_dl):


      X = X.to(device)
      y = y.to(device)

      y_hat = model(X).softmax(dim=1)

      loss = loss_fn(y_hat, y)

      del X, y

      loss.backward()
      optimizer.step()
      optimizer.zero_grad()

      acc_loss.append(loss.detach().cpu())

    train_losses.append(np.mean(acc_loss))

    acc_loss = []

    for X, y in valid_dl:
      X = X.to(device)
      y = y.to(device)
      y_hat = model(X).softmax(dim=1)
      loss = loss_fn(y_hat, y)
      acc_loss.append(loss.detach().cpu())

    valid_losses.append(np.mean(acc_loss))

    if valid_losses[-1] < best_loss:
      best_loss = valid_losses[-1]
      best_model = model

    if best_loss < 0.05:
      return best_model

    if epoch % 250 == 0:
      print(f'Epoch: {epoch}/{epochs}', f'Best loss: {best_loss}')

    if plot_loss:
      clear_output(wait=True)

      plt.grid()

      plt.plot(train_losses, linestyle = '--', color = "orange", label = 'Train Losses')
      plt.plot(valid_losses, linestyle = '--', color = "blue", label = 'Validation Losses')
      plt.xlabel('Epochs')
      plt.ylabel('Loss')

      plt.legend()

      plt.show()

  return best_model

# %%
from sklearn.metrics import accuracy_score, recall_score, f1_score, precision_score

def aux(train_dl, valid_dl, activation_fn, hidden_layers, lr, dropout, reg):

  clf = MLP(in_channels=22, hidden_channels=hidden_layers, activation_layer=activation_fn, dropout=dropout)
  print(clf)
  clf.train()

  optimizer = optim.SGD(clf.parameters(), lr=lr, weight_decay=reg)
  loss_fn = torch.nn.CrossEntropyLoss()

  best_model = train(clf, optimizer, loss_fn, train_dl, valid_dl, epochs = 20000)

  best_model.eval()

  predicted_train = best_model(X_train_tensor.float().to(device)).argmax(dim=1).cpu().detach()
  predicted_valid = best_model(X_valid_tensor.float().to(device)).argmax(dim=1).cpu().detach()

  return best_model, (accuracy_score(y_valid_tensor, predicted_valid), recall_score(y_valid_tensor, predicted_valid, average='weighted'), precision_score(y_valid_tensor, predicted_valid, average='weighted'), f1_score(y_valid_tensor, predicted_valid, average='weighted'))

# %%
def grid_search(train_dl, valid_dl, activation_fn, hidden_layers, learning_rate, dropout, regularization):
  best_acc = 0
  best_model = None
  args = None

  for act in activation_fn:
    for hl in hidden_layers:
      for lr in learning_rate:
        for drp in dropout:
          for reg in regularization:
            print(f'PARAMETROS: F.Act.: {act}; Layers: {hl}; LR: {lr}; Dropout: {drp}; Reg: {reg}')
            model, scores = aux(train_dl, valid_dl, act, hl, lr, drp, reg)
            acc, recall, precision, f1 = scores
            if acc > best_acc:
                best_acc = acc
                best_model = model
                args = f'PARAMETROS: F.Act.: {act}; Layers: {hl}; LR: {lr}; Dropout: {drp}; Reg: {reg}'
            print(f'SCORES: acc: {acc}; recall: {recall}; precision: {precision}; f1:{f1}\n')
  print(f"\n\nBest model args: {args}")
  return best_model

# %%
import warnings
warnings.filterwarnings("ignore")
# warnings.filterwarnings("default")

# %%
X_train_tensor = torch.tensor(X_train.values.astype(np.float32))
y_train_tensor = torch.tensor(y_train.values.astype(np.int64).ravel())

X_valid_tensor = torch.tensor(X_valid.values.astype(np.float32))
y_valid_tensor = torch.tensor(y_valid.values.astype(np.int64).ravel())

train_dataset = torch.utils.data.TensorDataset(X_train_tensor, y_train_tensor)
valid_dataset = torch.utils.data.TensorDataset(X_valid_tensor, y_valid_tensor)

train_dl = torch.utils.data.DataLoader(train_dataset, batch_size = 256, shuffle = True, num_workers=2)
valid_dl = torch.utils.data.DataLoader(valid_dataset, batch_size = 256, shuffle = True, num_workers=2)

hidden_channels = [[5], [5, 10]]
actv_fns = [torch.nn.ReLU, torch.nn.Sigmoid, torch.nn.Tanh]
learning_rates = [0.1, 0.01]
dropout = [0,0.1]
regularization = [0, 0.01]

#best_model = grid_search(train_dl, valid_dl, actv_fns, hidden_channels, learning_rates, dropout, regularization)

# %% [markdown]
# # RF
